# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulrajan16/python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing pandas library
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import fetch_openml

# Load the Boston dataset from OpenML
boston = fetch_openml(name='boston')

# Access features and target variable
X, y = boston.data, boston.target

# Now you can use X and y for your machine learning tasks
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:301: UserWarning: Multiple active versions of the dataset matching the name boston exist. Versions may be fundamentally different, returning version 1.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
type(boston)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(boston)
# Out:
# {'data':         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
boston_df = pd.DataFrame(boston.data,columns = boston.feature_names)
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
boston_df.shape
# Out:
# (506, 13)

# %%
type(boston_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# importing a data from CSV file into a pandas Dataframe

# %%
diabetics_df=pd.read_csv('/content/diabetes.csv')

# %%
type(diabetics_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetics_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetics_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the file from excel sheet to a pandas dataframe
# pd.read_excel('file path')

# %% [markdown]
# Exporting the Pandas DataFrame to an excel File:
#
# df.to_excel('filename')

# %%
boston_df.to_csv('boston_dataset.csv')

# %% [markdown]
# Inspecting a DataFrame

# %%
#finding the number of rows & columns
boston_df.shape
# Out:
# (506, 13)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    category
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    category
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: category(2), float64(11)
# memory usage: 45.1 KB

# %%
boston_df.value_counts('LSTAT')
# Out:
# LSTAT
# 18.13    3
# 8.05     3
# 7.79     3
# 6.36     3
# 14.10    3
#         ..
# 9.16     1
# 9.14     1
# 9.10     1
# 9.09     1
# 37.97    1
# Name: count, Length: 455, dtype: int64

# %%
# finding the number of missing values
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
diabetics_df.value_counts('Insulin')
# Out:
# Insulin
# 0      374
# 105     11
# 140      9
# 130      9
# 120      8
#       ...
# 193      1
# 191      1
# 188      1
# 184      1
# 846      1
# Name: count, Length: 186, dtype: int64

# %%
diabetics_df.groupby('Insulin').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness        BMI  \
# Insulin
# 0           4.433155  119.409091      67.473262      11.508021  30.943316
# 14          0.000000  180.000000      78.000000      63.000000  59.400000
# 15          2.000000   68.000000      62.000000      13.000000  20.100000
# 16          2.000000   88.000000      58.000000      26.000000  28.400000
# 18          2.000000   91.000000      65.000000      30.500000  36.450000
# ...              ...         ...            ...            ...        ...
# 579         1.000000  172.000000      68.000000      49.000000  42.400000
# 600         8.000000  124.000000      76.000000      24.000000  28.700000
# 680         0.000000  165.000000      90.000000      33.000000  52.300000
# 744         4.000000  197.000000      70.000000      39.000000  36.700000
# 846         1.000000  189.000000      60.000000      23.000000  30.100000
#
#          DiabetesPedigreeFunction        Age   Outcome
# Insulin
# ...

# %% [markdown]
# Statistical Measures

# %%
boston_df.count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# dtype: int64

# %%
# mean value - column wise
boston_df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-56f1567b5e6c> in <cell line: 2>()
#       1 # mean value - column wise
# ----> 2 boston_df.mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11199         **kwargs,
#   11200     ) -> Series | float:
# > 11201         return self._stat_function(
#   11202             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203         )
#
# ...

# %%
# standard deviation - column wise
boston_df.std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-6219e5384229> in <cell line: 2>()
#       1 # standard deviation - column wise
# ----> 2 boston_df.std()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11422             **kwargs,
#   11423         ):
# > 11424             return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11425
#   11426         setattr(cls, "std", std)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11135         **kwargs,
#   11136     ) -> Series | float:
# > 11137         return self._stat_function_ddof(
#   11138             "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   11139         )
#
# ...

# %%
# minimum value
boston_df.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f87b84d9c6d0> in <cell line: 2>()
#       1 # minimum value
# ----> 2 boston_df.min()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in min(self, axis, skipna, numeric_only, **kwargs)
#   11667             **kwargs,
#   11668         ):
# > 11669             return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11670
#   11671         setattr(cls, "min", min)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in min(self, axis, skipna, numeric_only, **kwargs)
#   11167         **kwargs,
#   11168     ):
# > 11169         return self._stat_function(
#   11170             "min",
#   11171             nanops.nanmin,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
# ...
